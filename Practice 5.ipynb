# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

#Define the OSM file and street_type_re re
OSMFILE = "wallawalla.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

#Use the expected array in order to determine street types to exclude from the analysis
expected = []

#Use the mapping dictionary in order to 
mapping = { "Ave": "Avenue",
            "Pl": "Place",
            "St": "Street",
            "Steet": "Street",
            "ave": "Avenue"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "rb")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping.keys():
            name = mapping[street_type]
    return name


def part1():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

def part2():
    for st_type, ways in st_types.items():
        for name in ways:
            m = street_type_re.search(name)
            if m:
                street_type = m.group()
            if street_type in mapping.keys():
                better_name = update_name(name, mapping)
                print (name, "=>", better_name)

# %%
part1()
# Out:
# {'Ave': {'S College Ave'},
#  'Avenue': {'Bel Air Avenue',
#             'Boyer Avenue',
#             'California Avenue',
#             'Central Avenue',
#             'Chapelwood Avenue',
#             'Criscola Avenue',
#             'Dawning Avenue',
#             'Delaware Avenue',
#             'East Isaacs Avenue',
#             'East Rees Avenue',
#             'Electric Avenue',
#             'Fleetwood Avenue',
#             'Francis Avenue',
#             'Maple Avenue',
#             'North 13th Avenue',
#             'North 4th Avenue',
#             'North College Avenue',
#             'North Wilbur Avenue',
#             'Northeast Ash Avenue',
#             'Northeast Birch Avenue',
#             'Northeast Cargill Avenue',
#             'Northeast Cedar Avenue',
#             'Northeast Damson Avenue',
#             'Northeast Della Avenue',
#             'Northeast Maple Avenue',
#             'Northeast Spitzenburg Avenue',
#             'Northwest Evans Avenue',
#             'Pacific Avenue',
#             'Penrose Avenue',
#             'Portland Avenue',
#             'School Avenue',
#             'Sky Avenue',
#             'South 1st Avenue',
#             'South 2nd Avenue',
#             'South 3rd Avenue',
#             'South 4th Avenue',
#             'South 9th Avenue',
#             'South Bellevue Avenue',
#             'South College Avenue',
#             'South Wilbur Avenue',
#             'Southeast Ash Avenue',
#             'Southeast Birch Avenue',
#             'Southeast Broadway Avenue',
#             'Southeast Cedar Avenue',
#             'Southeast Date Avenue',
#             'Southeast Elm Avenue',
#             'Southeast Justice Avenue',
#             'Southeast Larch Avenue',
#             'Southeast Red Oak Avenue',
#             'Southwest Bade Avenue',
#             'Southwest Davis Avenue',
#             'Southwest Evans Avenue',
#             'Sprague Avenue',
#             'Troutdale Avenue',
#             'Villa Avenue',
#             'Walla Walla Avenue',
#             'Wallula Avenue',
#             'Wellington Avenue',
#             'Westfair Avenue',
#             'Wilbur Avenue'},
#  'Boulevard': {'Southeast Meadowbrook Boulevard'},
#  'Circle': {'Parkwood Circle', 'Business One Circle'},
#  'Court': {'Carey Court',
#            'Chisholm Court',
#            'Clark Court',
#            'Clay Court',
#            'Covey Court',
#            'Crystal Court',
#            'Destitio Court',
#            'Fern Court',
#            'Jillian Court',
#            'Kimberly Court',
#            'Kobe Court',
#            'Livingston Court',
#            'Matara Court',
#            'Milan Court',
#            'Moorbrook Court',
#            'Northeast Mulberry Court',
#            'Opp Court',
#            'Reeves Court',
#            'Roosevelt Court',
#            'Sarita Court',
#            'Southeast Clover Court',
#            'Southeast Grassland Court',
#            'Southeast Hickory Court',
#            'Southeast Sunflower Court'},
#  'Drive': {'Alpine Drive',
#            'Assumption Drive',
#            'Bandra Drive',
#            'Baumeister Drive',
#            'Beacon Drive',
#            'Berney Drive',
#            'Blalock Drive',
#            'Blue Mountain Drive',
#            'Bosley Drive',
#            'Boyer Drive',
#            'Brevor Drive',
#            'Brookside Drive',
#            'Canary Drive',
#            'Cardinal Drive',
#            'Cascade Drive',
#            'Celestia Drive',
#            'Chestnut Drive',
#            'Cookerly Drive',
#            'Crawford Drive',
#            'Creekside Drive',
#            'Crestline Drive',
#            'Dewey Drive',
#            'Discovery Drive',
#            'Dow Drive',
#            'Durum Drive',
#            'East Whitman Drive',
#            'Edwards Drive',
#            'Falbo Drive',
#            'Francis Drive',
#            'Frazier Drive',
#            'Garden Drive',
#            'Gemstone Drive',
#            'Glen Erin Drive',
#            'Granite Drive',
#            'Hawk Drive',
#            'Heron Drive',
#            'Highland Park Drive',
#            'Hillbrooke Drive',
#            'Hillcrest Drive',
#            'Kensington Drive',
#            'Landen Drive',
#            'Lark Drive',
#            'Leonard Drive',
#            'Linda Drive',
#            'Lodge Drive',
#            'Lowell Drive',
#            'Magnoni Drive',
#            'Martin Drive',
#            'Maxson Drive',
#            'Milburn Drive',
#            'Mockingbird Drive',
#            'Mountain Park Drive',
#            'Mountain View Drive',
#            'Newgate Drive',
#            'North Sentry Drive',
#            'Northeast Tremont Drive',
#            'Olympia Drive',
#            'Rainier Drive',
#            'Robin Drive',
#            'Scarpelli Drive',
#            'Scenic View Drive',
#            'Shasta Drive',
#            'Southeast Cedar Bend Drive',
#            'Southeast Colonial Drive',
#            'Southeast Commercial Drive',
#            'Southeast Constitution Drive',
#            'Southeast Crestlane Drive',
#            'Southeast Davin Drive',
#            'Southeast Garrison Drive',
#            'Southeast Harvest Drive',
#            'Southeast Highland Park Drive',
#            'Southeast Marine Drive',
#            'Southeast Sentry Drive',
#            'Southeast Tuscany Drive',
#            'Stadium Drive',
#            'Studebaker Drive',
#            'Sunny Drive',
#            'Sunset Drive',
#            'Trentwood Drive',
#            'Tull Drive',
#            'Valley View Drive',
#            'Vinehill Drive',
#            'Wainwright Drive',
#            'Wallowa Drive',
#            'Wauna Vista Drive',
#            'West Whitman Drive'},
#  'Isaacs': {'E Isaacs'},
#  'Lane': {'Andy Lane',
#           'Benina Lane',
#           'Bobolink Lane',
#           'Brook Lane',
#           'Bryans Lane',
#           'Chickadee Lane',
#           'Dogwood Lane',
#           'Dove Lane',
#           'Dusty Lane',
#           'Eagle Lane',
#           'Fire Station Lane',
#           'Fishtrap Lane',
#           'Foothills Lane',
#           'Hart Lane',
#           'Havasu Lane',
#           'Iris Lane',
#           'Jewel Lane',
#           'Jordan Lane',
#           'Kiwanis Lane',
#           'Locati Lane',
#           'Mallard Lane',
#           'Martonick Lane',
#           'Murphy Lane',
#           'Northeast Beechwood Lane',
#           'Northeast Bunky Lane',
#           'Northeast Cottonwood Lane',
#           'Northeast Danner Lane',
#           'Northeast Flowers Lane',
#           'Northeast Ivy Lane',
#           'Northeast Sedona Lane',
#           'Northeast Tulip Lane',
#           'Northwest Earl Lane',
#           'Northwest Laurella Lane',
#           'Northwest Ruby Lane',
#           'Northwest Schnabel Lane',
#           'Northwest Vera Lane',
#           'Oconner Lane',
#           'Osprey Lane',
#           'Payton Lane',
#           'Raven Lane',
#           'Rex Lane',
#           'Ricky Lane',
#           'Riggs Lane',
#           'Roff Lane',
#           'Roseville Lane',
#           'Sandpiper Lane',
#           'Shady Tree Lane',
#           'Shirrod Lane',
#           'Snitily Lane',
#           'Songbird Lane',
#           'Southeast Bliss Lane',
#           'Southeast Independence Lane',
#           'Stettler Lane',
#           'Stonyhaven Lane',
#           'Swainson Lane',
#           'Tawny Lane',
#           'Trio Lane',
#           'Whittington Lane',
#           'Winemakers Lane',
#           'Woodbury Lane'},
#  'Loop': {'Bedford Loop',
#           'Karol Loop',
#           'Northwest Spagnuolo Loop',
#           'Rodeo Loop',
#           'Talon Loop',
#           'Woodmere Loop'},
#  'Pl': {'Summit Pl'},
#  'Place': {'Agate Place',
#            'Belmont Place',
#            'Brentwood Place',
#            'Celestia Place',
#            'Cotter Place',
#            'Crestview Place',
#            'Delmont Place',
#            'Dice Place',
#            'Echo Place',
#            'Edgemont Place',
#            'Elliott Place',
#            'Flint Place',
#            'Helfer Place',
#            'Hood Place',
#            'Huntington Place',
#            'Kathleen Place',
#            'Kelly Place',
#            'Larkspur Place',
#            'Liberty Place',
#            'Mc Kay Place',
#            'Mead Place',
#            'Meadowbrook Place',
#            'Mica Place',
#            'Minute Place',
#            'Northeast Damson Place',
#            'Northeast Elder Place',
#            'Northeast Fernwood Place',
#            'Northeast Kingwood Place',
#            'Northeast Redwood Place',
#            'Northeast Sprucewood Place',
#            'Parkside Place',
#            'Parkview Place',
#            'Rustic Place',
#            'Shale Place',
#            'Southeast Admiral Place',
#            'Southeast Brigade Place',
#            'Southeast Commodore Place',
#            'Southeast Ensign Place',
#            'Southeast Freedom Place',
#            'Southeast Pepperidge Place',
#            'Southeast Vista Place',
#            'Stanford Place',
#            'Stone Creek Place',
#            'Studebaker Place',
#            'Sullivan Place',
#            'Tietan Place',
#            'Twin Creek Place',
#            'Yellowhawk Place'},
#  'Road': {'Abbott Road',
#           'Aubin Road',
#           'Dalles Military Road',
#           'Highland Road',
#           'Lower Waitsburg Road',
#           'Merrill Road',
#           'Middle Waitsburg Road',
#           'Mojonnier Road',
#           'Northeast Deccio Road',
#           'Northeast Lambert Road',
#           'Reservoir Road',
#           'Shelton Road',
#           'Sheridan Road',
#           'Taumarson Road',
#           'Trimball Road'},
#  'Run': {'Pheasant Run', 'Quail Run'},
#  'St': {'SW 10th St'},
#  'Steet': {'Northwest Maria Steet'},
#  'Street': {'Amelia Street',
#             'Ankeny Street',
#             'Annie Laurie Street',
#             'Artesia Street',
#             'Ash Street',
#             'Aspen Street',
#             'Avalon Street',
#             'Avery Street',
#             'Balm Street',
#             'Belle Street',
#             'Belroy Street',
#             'Bethel Street',
#             'Bonnie Brae Street',
#             'Bonsella Street',
#             'Bradley Street',
#             'Bridge Street',
#             'Brock Street',
#             'Bryant Street',
#             'Burns Street',
#             'Bush Street',
#             'Carl Street',
#             'Carriage Street',
#             'Catherine Street',
#             'Cedar Street',
#             'Center Street',
#             'Chandler Street',
#             'Chase Street',
#             'Chelan Street',
#             'Cherokee Street',
#             'Clark Street',
#             'Clay Street',
#             'Columbia Street',
#             'Commercial Street',
#             'Cottingham Street',
#             'Craig Street',
#             'Crescent Street',
#             'Crown Street',
#             'Cushing Street',
#             'Cypress Street',
#             'Dakota Street',
#             'Davis Street',
#             'Dawson Street',
#             'Defence Street',
#             'Delmas Street',
#             'Delmont Street',
#             'Donald Street',
#             'Drumheller Street',
#             'Durant Street',
#             'Eagan Street',
#             'Earnest Street',
#             'East Alder Street',
#             'East Birch Street',
#             'East Cherry Street',
#             'East Chestnut Street',
#             'East Main Street',
#             'East Maple Street',
#             'East Melrose Street',
#             'East Morton Street',
#             'East Oak Street',
#             'East Pine Street',
#             'East Poplar Street',
#             'East Rose Street',
#             'East Sumach Street',
#             'East Tietan Street',
#             'East Walnut Street',
#             'Easy Street',
#             'Edgewood Street',
#             'Edmond Street',
#             'Empire Street',
#             'Estrella Street',
#             'Evergreen Street',
#             'Fairmont Street',
#             'Fern Street',
#             'Figueroa Street',
#             'Frankland Street',
#             'Frisco Street',
#             'Fulton Street',
#             'Garden Street',
#             'Garfield Street',
#             'Garrison Street',
#             'George Street',
#             'Gladys Street',
#             'Grant Street',
#             'Granville Street',
#             'Green Street',
#             'Grove Street',
#             'Harrison Street',
#             'Hatch Street',
#             'Hawthorne Street',
#             'Hobson Street',
#             'Holly Street',
#             'Home Street',
#             'Hope Street',
#             'Imperial Street',
#             'J Street',
#             'Jackson Street',
#             'Jefferson Street',
#             'Juniper Street',
#             'K Street',
#             'Kenneth Street',
#             'Kenwood Street',
#             'L Street',
#             'Laurel Street',
#             'Lenore Street',
#             'Leonard Street',
#             'Lewis Street',
#             'Liberty Street',
#             'Lincoln Street',
#             'Linden Street',
#             'Locust Street',
#             'Loubeck Street',
#             'Malcolm Street',
#             'Manila Street',
#             'Marcus Street',
#             'Mc Cabe Street',
#             'McAuliff Street',
#             'McKinley Street',
#             'Meadow Street',
#             'Merriam Street',
#             'Military Street',
#             'Modoc Street',
#             'Monroe Street',
#             'Myrtle Street',
#             'N Roosevelt Street',
#             'Natches Street',
#             'Newell Street',
#             'North Bellevue Street',
#             'North Blue Street',
#             'North Clinton Street',
#             'North Colville Street',
#             'North Division Street',
#             'North Madison Street',
#             'North Main Street',
#             'North Palouse Street',
#             'North Park Street',
#             'North Roosevelt Street',
#             'North Touchet Street',
#             'North Tukanon Street',
#             'Northeast A Street',
#             'Northeast C Street',
#             'Northeast Larch Street',
#             'Northwest B Street',
#             'Olive Street',
#             'Omak Street',
#             'Orchard Street',
#             'Oriole Street',
#             'Otis Street',
#             'Parish Street',
#             'Pearson Street',
#             'Pleasant Street',
#             'Pomona Street',
#             'Ponti-Moro Street',
#             'Rome Street',
#             'Ruth Street',
#             'Saint John Street',
#             'Schick Street',
#             'Shady Rill Street',
#             'Sinclair Street',
#             'South Blue Street',
#             'South Clinton Street',
#             'South Colville Street',
#             'South Division Street',
#             'South Gose Street',
#             'South Howard Street',
#             'South Hussey Street',
#             'South Madison Street',
#             'South Palouse Street',
#             'South Park Street',
#             'South Roosevelt Street',
#             'South Spokane Street',
#             'Southeast 10th Street',
#             'Southeast 11th Street',
#             'Southeast 12th Street',
#             'Southeast 2nd Street',
#             'Southeast 3rd Street',
#             'Southeast 4th Street',
#             'Southeast 5th Street',
#             'Southeast 6th Street',
#             'Southeast 8th Street',
#             'Southeast 9th Street',
#             'Southeast Lamperti Street',
#             'Southeast Market Street',
#             'Southeast Tamarack Street',
#             'Southwest 12th Street',
#             'Southwest 1st Street',
#             'Southwest 2nd Street',
#             'Southwest 3rd Street',
#             'Southwest 4th Street',
#             'Southwest 5th Street',
#             'Southwest 6th Street',
#             'Southwest 7th Street',
#             'Spring Street',
#             'Stahl Street',
#             'Stanton Street',
#             'Star Street',
#             'Statesman Street',
#             'Stone Street',
#             'Stuart Street',
#             'Sturm Street',
#             'Sunbar Street',
#             'Sycamore Street',
#             'Thorne Street',
#             'Tillamook Street',
#             'Truman Street',
#             'Umatilla Street',
#             'Union Street',
#             'University Street',
#             'Valencia Street',
#             'Wallace Street',
#             'Washington Street',
#             'Waverly Street',
#             'West Alder Street',
#             'West Chestnut Street',
#             'West Main Street',
#             'West Maple Street',
#             'West Moore Street',
#             'West Morton Street',
#             'West Poplar Street',
#             'West Rose Street',
#             'West Tietan Street',
#             'West Walnut Street',
#             'Wheatland Street',
#             'White Street',
#             'Whitman Street',
#             'Wildwood Street',
#             'Willard Street',
#             'Wilshire Street',
#             'Wilson Street',
#             'Winnebago Street',
#             'Withva Street',
#             'Woodlawn Street',
#             'Yakima Street',
#             'Yellowstone Street',
#             'York Street'},
#  'Terrace': {'Braeburn Terrace', 'Alvarado Terrace', 'Valley View Terrace'},
#  'Way': {'Garrison Village Way',
#          'North Tausick Way',
#          'Plaza Way',
#          'Singleton Way',
#          'South Tausick Way',
#          'Southeast Liberty Way',
#          'Southeast Vintage Way',
#          'Southwest Academy Way',
#          'West Plaza Way',
#          'Yellowhawk Way'},
#  'ave': {'south wilbur ave'}}

# %%
part2()
# Out:
# south wilbur ave => Avenue
# SW 10th St => Street
# S College Ave => Avenue
# Northwest Maria Steet => Street
